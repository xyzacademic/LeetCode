# %% [markdown]
# ![image.png](attachment:752755f1-d07f-4771-b5be-47543584601f.png)

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
class Solution:
    def reverseList(self, head: ListNode) -> ListNode:

        cur = None

        while head:
            tmp = head.next 
            head.next = cur 
            cur = head 
            head = tmp 
        
        return cur

# %% [markdown]
# ![image.png](attachment:1707cdc2-1aa8-410f-8df3-ccacb1da0c3e.png)

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
        
class Solution:
    def mergeTwoLists(self, l1: ListNode, l2: ListNode) -> ListNode:
        # create a new ListNode
        new_head = ListNode()
        tmp = new_head
        
        # quit while loop if any list is empty
        while l1 and l2:
            if l1.val <= l2.val:
                tmp.next = ListNode(l1.val)
                l1 = l1.next 
            else:
                tmp.next = ListNode(l2.val)
                l2 = l2.next 
            tmp = tmp.next
        
        # concatenate to the rest one
        tmp.next = l1 if l1 else l2 
    
        return new_head.next

# %% [markdown]
# ID:141
# =
# ![image.png](attachment:26277c56-1230-418c-9f21-da5470267443.png)

# %%
class ListNode:
    def __init__(self, x):
        self.val = x
        self.next = None

class Solution:
    def hasCycle(self, head: ListNode) -> bool:
        if not head or not head.next:
            return False 
        
        slow = head 
        fast = head.next 

        while fast and fast.next:
            fast = fast.next.next 
            slow = slow.next 
            if fast == slow:
                return True 
        
        return False

# %% [markdown]
# ID:160
# =
#
# ![image.png](attachment:93253f2b-6736-4889-bd22-bc277237becc.png)

# %%
class Solution:
    def getIntersectionNode(self, headA: ListNode, headB: ListNode) -> ListNode:

        pa = headA
        pb = headB 
        
        while pa != pb:
            pa = pa.next if pa else headB 
            pb = pb.next if pb else headA 
        
        return pa

# %% [markdown]
# ID:83
# =
# ![image.png](attachment:c292c796-7e02-4556-9e20-6e23a393b8f0.png)

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
class Solution:
    def deleteDuplicates(self, head: ListNode) -> ListNode:

        cur = head

        while cur:
            while cur.next and cur.next.val == cur.val:
                cur.next = cur.next.next 
            cur = cur.next 
        return head
